# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
LMPD_Analytics = pd.read_csv("../Data/LMPD_crimes.csv")

LMPD_Analytics
# Out:
#       incident_number          date_reported          date_occurred  badge_id  \
# 0        LMPD25147130  12/10/2025 3:57:00 PM   2/20/2024 5:00:00 AM    8701.0
# 1        LMPD25144947   12/5/2025 5:28:00 PM  11/16/2024 5:00:00 AM    8701.0
# 2        LMPD25140113  11/24/2025 4:22:00 AM    7/9/2024 4:00:00 AM    8631.0
# 3        LMPD25139843  11/23/2025 2:37:00 PM  11/15/2024 9:00:00 PM    8560.0
# 4        LMPD25020252   2/24/2025 8:52:00 PM  12/19/2024 3:51:00 AM    8646.0
# ...               ...                    ...                    ...       ...
# 70771    LMPD23110521  11/12/2023 1:00:00 PM   1/16/2024 5:00:00 AM    7444.0
# 70772    LMPD23110062  11/10/2023 9:32:00 PM    2/3/2024 9:54:00 PM    5434.0
# 70773    LMPD23109383   11/9/2023 1:11:00 PM   4/13/2024 9:53:00 AM    7755.0
# 70774    LMPD23109575  11/8/2023 11:00:00 PM   10/5/2024 1:47:00 AM    8515.0
# 70775    LMPD23107772   11/5/2023 7:35:00 PM  3/30/2024 12:00:00 AM    8075.0
#
#        offense_classification  \
# 0            19 THEFT FR BLDG
# 1      29 FRAUD IMPERSONATION
# 2      29 FRAUD IMPERSONATION
# 3               14 AUTO THEFT
# 4              18 SHOPLIFTING
# ...                       ...
# 70771      46 FAMILY OFFENSES
# 70772      33 STOLEN PROPERTY
# 70773      33 STOLEN PROPERTY
# 70774   56 ALL OTHER OFFENSES
# 70775      33 STOLEN PROPERTY
#
#                                        offense_code_name nibrs_code  \
# 0      TBUT OR DISP FROM BUILDING $1,000 < $10,000 51...        23D
# 1      THEFT OF IDENTITY OF ANOTHER WITHOUT CONSENT 5...        26C
# 2      THEFT OF IDENTITY OF ANOTHER WITHOUT CONSENT 5...        26C
# 3      TBUT OR DISP AUTO $1,000 < $10,000 514.030 241...        240
# 4             TBUT OR DISP SHOPLIFTING 514.030 24230 23C        23C
# ...                                                  ...        ...
# 70771    VIOLATION OF KENTUCKY EPO/DVO 403.763 02763 90F        90F
# 70772  RECEIVING STOLEN PROPERTY $1,000 < $10,000 514...        280
# 70773  RECEIVING STOLEN PROPERTY (FIREARM) 514.110 28...        280
# 70774      RECOVERY OF STOLEN PROPERTY ***.*** 03016 90Z        90Z
# 70775  RECEIVING STOLEN PROPERTY (FIREARM) 514.110 28...        280
#
#       nibrs_group_name was_offense_completed lmpd_division lmpd_beat  \
# 0                    A                   YES  8TH DIVISION       812
# 1                    A                   YES  4TH DIVISION       424
# 2                    A                   YES  8TH DIVISION       824
# 3                    A                   YES  2ND DIVISION       223
# 4                    A                   YES  3RD DIVISION       315
# ...                ...                   ...           ...       ...
# 70771                B                    NO  3RD DIVISION       331
# 70772                A                   YES  3RD DIVISION       331
# 70773                A                   YES  4TH DIVISION       412
# 70774                B                    NO  4TH DIVISION       423
# 70775                A                   YES  8TH DIVISION       815
#
#                             location_category              block_address  \
# 0                              RESIDENCE/HOME    5000 BLOCK CLIFFWOOD RD
# 1                              RESIDENCE/HOME    500 BLOCK LONGFIELD AVE
# 2                              RESIDENCE/HOME   100 BLOCK LA FONTENAY DR
# 3      HIGHWAY/ ROAD/ ALLEY/ STREET/ SIDEWALK       1300 BLOCK S 26TH ST
# 4                        GROCERY/ SUPERMARKET       9900 BLOCK DIXIE HWY
# ...                                       ...                        ...
# 70771                          RESIDENCE/HOME      2800 BLOCK DE MEL AVE
# 70772                          RESIDENCE/HOME       5300 BLOCK MILNER RD
# 70773       OTHER RESIDENCE (APARTMENT/CONDO)     700 BLOCK S HANCOCK ST
# 70774                          RESIDENCE/HOME     3600 BLOCK KAHLERT AVE
# 70775               DEPARTMENT/DISCOUNT STORE  7900 BLOCK SHELBYVILLE RD
#
#                  city zip_code  ObjectId
# 0          LOUISVILLE    40222         1
# 1          LOUISVILLE    40215         2
# 2      DOUGLASS HILLS    40223         3
# 3          LOUISVILLE    40210         4
# 4          LOUISVILLE    40272         5
# ...               ...      ...       ...
# 70771      LOUISVILLE    40214     70772
# 70772      LOUISVILLE    40216     70773
# 70773      LOUISVILLE    40203     70774
# 70774      LOUISVILLE    40215     70775
# 70775      LOUISVILLE    40222     70776
#
# [70776 rows x 16 columns]

# %%
LMPD_Analytics.head()
# Out:
#   incident_number          date_reported          date_occurred  badge_id  \
# 0    LMPD25147130  12/10/2025 3:57:00 PM   2/20/2024 5:00:00 AM    8701.0
# 1    LMPD25144947   12/5/2025 5:28:00 PM  11/16/2024 5:00:00 AM    8701.0
# 2    LMPD25140113  11/24/2025 4:22:00 AM    7/9/2024 4:00:00 AM    8631.0
# 3    LMPD25139843  11/23/2025 2:37:00 PM  11/15/2024 9:00:00 PM    8560.0
# 4    LMPD25020252   2/24/2025 8:52:00 PM  12/19/2024 3:51:00 AM    8646.0
#
#    offense_classification                                  offense_code_name  \
# 0        19 THEFT FR BLDG  TBUT OR DISP FROM BUILDING $1,000 < $10,000 51...
# 1  29 FRAUD IMPERSONATION  THEFT OF IDENTITY OF ANOTHER WITHOUT CONSENT 5...
# 2  29 FRAUD IMPERSONATION  THEFT OF IDENTITY OF ANOTHER WITHOUT CONSENT 5...
# 3           14 AUTO THEFT  TBUT OR DISP AUTO $1,000 < $10,000 514.030 241...
# 4          18 SHOPLIFTING         TBUT OR DISP SHOPLIFTING 514.030 24230 23C
#
#   nibrs_code nibrs_group_name was_offense_completed lmpd_division lmpd_beat  \
# 0        23D                A                   YES  8TH DIVISION       812
# 1        26C                A                   YES  4TH DIVISION       424
# 2        26C                A                   YES  8TH DIVISION       824
# 3        240                A                   YES  2ND DIVISION       223
# 4        23C                A                   YES  3RD DIVISION       315
#
#                         location_category             block_address  \
# 0                          RESIDENCE/HOME   5000 BLOCK CLIFFWOOD RD
# 1                          RESIDENCE/HOME   500 BLOCK LONGFIELD AVE
# 2                          RESIDENCE/HOME  100 BLOCK LA FONTENAY DR
# 3  HIGHWAY/ ROAD/ ALLEY/ STREET/ SIDEWALK      1300 BLOCK S 26TH ST
# 4                    GROCERY/ SUPERMARKET      9900 BLOCK DIXIE HWY
#
#              city zip_code  ObjectId
# 0      LOUISVILLE    40222         1
# 1      LOUISVILLE    40215         2
# 2  DOUGLASS HILLS    40223         3
# 3      LOUISVILLE    40210         4
# 4      LOUISVILLE    40272         5

# %%
LMPD_Analytics['lmpd_division'].unique()
# Out:
# array(['8TH DIVISION', '4TH DIVISION', '2ND DIVISION', '3RD DIVISION',
#        '1ST DIVISION', '6TH DIVISION', '7TH DIVISION', '5TH DIVISION',
#        nan, 'CAL', 'OOJ', 'WEST BUECHEL', 'JEFFERSONTOWN', 'MIDDLETOWN',
#        'SHIVELY', 'ST MATTHEWS', 'LYNDON', 'INDIAN HILLS', 'AUDUBON PARK',
#        'ANCHORAGE', 'LMPD', 'PROSPECT', 'OLDHAM'], dtype=object)

# %%
LMPD_Analytics['offense_classification'].unique()
# Out:
# array(['19 THEFT FR BLDG', '29 FRAUD IMPERSONATION', '14 AUTO THEFT',
#        '18 SHOPLIFTING', '23 THEFT OTHER', '28 FRAUD CREDIT CARD/ATM',
#        '12 INTIMIDATION', '56 ALL OTHER OFFENSES', '13 BURGLARY',
#        '22 THEFT MV PARTS', '32 EMBEZZLEMENT', '4 FORCIBLE RAPE',
#        '24 VANDALISM', '43 PROSTITUTION', '26 COUNTERFEITING',
#        '21 THEFT FR VEH', '46 FAMILY OFFENSES', '36 INCEST',
#        '37 STAT RAPE', '5 SODOMY FORCE', '7 FORCIBLE FONDLING',
#        '38 PORNOGRAPHY', nan, '9 AGGRAVATED ASSAULT',
#        '15 UNAUTHORIZED USE', '34 NARCOTICS', '33 STOLEN PROPERTY',
#        '23 LARCENY', '27 FRAUD', '46 WPNS LAW VIOLATION',
#        '11 SIMPLE ASSAULT', '32 THEFT FR BLDG', '1 HOMICIDE',
#        '35 NARCOTICS EQUIP', '55 TRESPASSING', '8 ROBBERY',
#        '99 NON-REPORTABLE', '10 KIDNAPPING ONLY',
#        '3 JUSTIFIABLE HOMICIDE', '20 THEFT FR VEND MACHINE',
#        '51 DISORDERLY CONDUCT', '52 DRUNKENNESS', '50 DRUNK DRIVING',
#        '56 ALL OTHER CRIMES', '58 ARSON', '47 FAMILY OFFENSES',
#        '17 PICK POCKET', '54 VOYEURISM', '25 EXTORTION',
#        '16 PURSE SNATCH', '49 LOITERING/CURFEW VIOL',
#        '2 NEGLIGENT HOMICIDE', '45 BRIBERY', '56 NON REPORTABLE',
#        '53 LIQUOR LAW VIOLATION', '44 PROMOTING PROSTITUTION'],
#       dtype=object)

# %%
LMPD_Analytics['offense_code_name'].unique()
# Out:
# array(['TBUT OR DISP FROM BUILDING $1,000 < $10,000 514.030 24162 23D',
#        'THEFT OF IDENTITY OF ANOTHER WITHOUT CONSENT 514.160 23310 26C',
#        'TBUT OR DISP AUTO $1,000 < $10,000 514.030 24112 240',
#        'TBUT OR DISP SHOPLIFTING 514.030 24230 23C',
#        'THEFT BY DECEPTION INCLUDING COLD CHECKS $1,000 < $10,000 514.040(8)(b) 71287 23H',
#        'THEFT BY DECEPTION INCLUDING COLD CHECKS $10,000 OR MORE 514.040(8)(c) 71289 23H',
#        'FRAUDULENT USE OF A CREDIT CARD > $10,000 434.650(1)(B)(4) 71206 26B',
#        'TBUT OR DISP FROM BUILDING 514.030 24160 23D',
#        'HARASSMENT (NO PHYSICAL CONTACT) 525.070 02405 13C',
#        'UNLAWFUL ACCESS TO COMPUTER-1ST DEGREE 434.845 51260 90Z',
#        'TBUT OR DISP FIREARM 514.030 23100 23H',
#        'BURGLARY - 3RD DEGREE 511.040 22062 220',
#        'FRAUDULENT USE OF A CREDIT CARD $1000 < $10,000 434.650(1)(B)(2) 71204 26B',
#        'TERRORISTIC THREATENING 3RD DEGREE 508.080 00822 13C',
#        'THEFT OF MOTOR VEHICLE REGISTRATION PLATE/DECAL 186.990(6) 28200 23G',
#        'THEFT OF MAIL MATTER 514.140 23265 23H',
#        'TBUT OR DISP FROM BUILD $10,000 < $1,000,000 (EMBEZZLEMENT) 514.030 24163E 270',
#        'RAPE - 1ST DEGREE 510.040 10990 11A',
#        'HARASSING COMMUNICATIONS 525.080 02402 90Z',
#        'CRIMINAL MISCHIEF - 1ST DEGREE 512.020 01401 290',
#        'FRAUDULENT USE OF A CREDIT CARD $500 < $1000 434.650(1)(B)(1) 71202 26B',
#        'HUMAN TRAFFICKING - COMM SEX ACTIVITY (VICTIM< 18) 529.100 40063 64B',
#        'CRIMINAL POSSESSION FORGED INSTRUMENT-2ND DEGREE-IDENTIFY 516.060 25062 250',
#        'TBUT OR DISP AUTO $10,000 < $1,000,000 514.030 24113 240',
#        'TBUT OR DISP CONTENTS FROM VEH 514.030 24140 23F',
#        'KNOWINGLY EXPLOIT ADULT BY PERSON O/$300 209.990(5) 02034 90F',
#        'INCEST PERSON LESS THAN 18 BY PERSON 3 OR MORE YRS OLDER 530.020 36056 36A',
#        'RAPE - 3RD DEGREE 510.060 11165 36B',
#        'SODOMY - 3RD DEGREE 510.090 11205 11B',
#        'TBUT PARTS FROM VEHICLE $500 < $1,000 514.030 24241 23G',
#        'PROMOTING A MINOR U/16 IN SEX PERFORMANCE 531.320(2B) 37228 36B',
#        'SEXUAL ABUSE - 1ST DEGREE 510.110 11220 11D',
#        'POSSESS MATTER SEX PERFORMANCE BY MINOR O/12 < 18 1ST OFF 531.335(3) 37275 370',
#        'THEFT BY DECEPTION INCLUDING COLD CHECKS $10,000 OR MORE EMB514.040(8)(c) 71289E 270',
#        'MISUSE OF ELECTRONIC INFO-AUTOMATIC BANKING FUND TRANSFER 434.685(2) 21222 26B',
#        'CRIMINAL MISCHIEF-2ND DEGREE 512.030 01402 290',
#        'WANTON ENDANGERMENT 1ST - DISCHARGE OF FIREARM 508.060 13204 13A',
#        'TORTURE OF A DOG OR CAT 525.135 02573 720',
#        'UNAUTHORIZED USE OF MOTOR VEHICLE 1ST OFFENSE 514.100 00701 240',
#        'TBUT OR DISP FROM BUILDING $1,000 < $10,000 514.030 24162E 270',
#        'TBUT OR DISP FROM BUILDING $500 < $1,000 514.030 24161 23D',
#        'ASSAULT - 1ST DEGREE 508.010 13150 13A',
#        'RAPE - 1ST DEGREE - DOMESTIC VIOLENCE 510.040 10992 11A',
#        'TRF CON SUB 2ND DEG 1ST OFN (>= 20 DU DRUG UNSPEC SCH III 218A.1412 42455 35A',
#        'PROPERTY LOST OR ABANDONED NON CRIMINAL 67.592(1C) 03024 90Z',
#        'WANTON ENDANGERMENT-1ST DEGREE 508.060 13201 13A',
#        'CRIMINAL POSSESSION FORGED INSTRUMENT-1ST DEGREE-IDENTIFY 516.050 25061 250',
#        'THEFT BY DECEPTION INCLUDING COLD CHECKS 514.040(8) 71283 23H',
#        'RECEIVING STOLEN PROPERTY $500 < $1,000 514.110(3)(a) 28010 280',
#        'RECEIVING STOLEN PROPERTY $1,000 < $10,000 514.110(3)(b) 28012 280',
#        'FRAUDULENT USE OF A CREDIT CARD 434.650(1)(B) 71200 26B',
#        'THEFT BY DECEPTION INCLUDING COLD CHECKS 514.040(8) 71283E 270',
#        'BURGLARY - 2ND DEGREE 511.030 22061 220',
#        'TBUT OR DISP ALL OTHERS $1,000 < $10,000 514.030 24097 23H',
#        'THEFT BY FAIL TO MAKE REQ DISP OF PROPERTY $1,000 < $10,000 514.070(4)(b) 23494 26A',
#        'TBUT OR DISP ALL OTHERS $10,000 < $1,000,000 514.030 24098 23H',
#        'POSS HANDGUN BY MINOR 1ST OFFENSE 527.100 52206 520',
#        'RECOVERY OF STOLEN PROPERTY ***.*** 03016 90Z',
#        'ASSAULT - 4TH DEGREE (CHILD ABUSE) 508.030 00799 13B',
#        'TBUT OR DISP ALL OTHERS 514.030 24095 23H',
#        'THEFT BY DECEPTION INCLUDING COLD CHECKS $1,000 < $10,000 514.040(8)(b) 71287E 270',
#        'BURGLARY - 1ST DEGREE 511.020 22060 220',
#        'HUMAN TRAFFICKING - COMMERCIAL SEX ACTIVITY 529.100 40061 64B',
#        'THEFT BY FAIL TO MAKE REQ DISP OF PROPERTY $10,000 OR MORE 514.070(4)(c) 23496 26A',
#        'TBUT OR DISP BICYCLES $1,000 < $10,000 514.030 24122 23H',
#        'DOMESTIC ABUSE DUTIES OF LAW ENFORCEMENT 403.785 03018 90Z',
#        'ASSAULT - 4TH DEGREE (DOMESTIC VIOLENCE) NO VISIBLE INJURY 508.030 00797 13B',
#        'STRANGULATION 1ST DEGREE (DOMESTIC VIOLENCE RELATED) 508.170 13224 13A',
#        'SEXUAL ABUSE - 1ST DEGREE- VICTIM U/12 YOA 510.110 11221 11D',
#        'KNOWING WANTON/RECKLESS EXPLOIT OF ADULT BY PERSON $300 OR <209.990(7) 02037 90F',
#        'FAILURE TO COMPLY W/SEX OFFENDER REGISTRATION - 1ST OFF 17.510(11) 01680 90Z',
#        'TBUT OR DISP SHOPLIFTING $1,000 < $10,000 514.030 24232 23C',
#        'RAPE - 1ST DEGREE - VICTIM U/12 YEARS OF AGE 510.040 10996 11A',
#        'ASSAULT - 4TH DEGREE (NO VISIBLE INJURY) 508.030 00795 13B',
#        'TBUT OR DISP SHOPLIFTING $500 < $1,000 514.030 24231 23C',
#        'SODOMY - 1ST DEGREE - DOMESTIC VIOLENCE 510.070 11182 11B',
#        'DIST OF MATTER PORTRAYING SEX PERF BY MINOR UNDER 12 531.340 37293 370',
#        'POSSESS MATTER SEX PERFORMANCE BY MINOR UNDER / 12 531.335(3) 37278 370',
#        'TBUT PARTS FROM VEHICLE $1,000 < $10,000 514.030 24242 23G',
#        'INDECENT EXPOSURE - 1ST DEGREE - 1ST OFFENSE 510.148 01750 90Z',
#        'THEFT BY FAIL TO MAKE REQ DISP OF PROPERTY 514.070(4) 23490 26A',
#        'THEFT BY DECEPTION INCLUDING COLD CHECKS $500 < $1,000 514.040(8)(a) 71285 23H',
#        'RAPE - 1ST DEGREE - INCAPABLE OF CONSENT/PHYSICALLY HELPLESS510.040 10994 11A',
#        'THEFT OF SERVICES $500 < $1,000 514.060(4)(a) 23483 23H',
#        'TBUT OR DISP AUTO $500 < $1,000 514.030 24111 240',
#        'TBUT OR DISP FROM BUILDING 514.030 24160E 270',
#        'TBUT OR DISP ALL OTHERS $500 < $1,000 514.030 24096 23H',
#        'TBUT OR DISP FROM BUILDING $500 < $1,000 514.030 24161E 270',
#        'THEFT BY DECEPTION INCLUDE COLD CHECKS CLASS A 3+ IN 5 YRS 514.040(8)(d) 71291 23H',
#        'TBUT OR DISP FROM BUILDING $10,000 < $1,000,000 514.030 24163 23D',
#        'THEFT OF PROP MISLAID OR DELIVER BY IMISTAKE $500 < $1000 514.050(1)(a) 23474 23H',
#        'TERRORISTIC THREATENING 2ND DEGREE 508.078 00821 13C',
#        'ASSAULT - 4TH DEGREE (DOMESTIC VIOLENCE) MINOR INJURY 508.030 00798 13B',
#        'MURDER 507.020 09150 09A',
#        'DRUG PARAPHERNALIA - BUY/POSSESS 218A.500(2) 42081 35B',
#        'CRIMINAL TRESPASS-2ND DEGREE 511.070 02624 90J',
#        'FAIL OF NON-OWNER/OPER TO MAINTAIN REQ INS/SECURITY 1ST OFF 304.99-060 00482 90Z',
#        'POSS CONT SUB 1ST DEGREE 3RD > OFFENSE-COCAINE 218A.1415 42194 35A',
#        'ASSAULT - 4TH DEGREE (MINOR INJURY) 508.030 00796 13B',
#        'POSS OF MARIJUANA 218A.1422 42330 35A',
#        'HARASSMENT - PHYSICAL CONTACT - NO INJURY 525.070 02407 13B',
#        'POSS CONTROLLED SUB 1ST DEGREE 1ST OFF (METHAMPHETAMINE) 218.1415 42215 35A',
#        'ROBBERY - 1ST DEGREE 515.020 12002 120',
#        'ASSAULT - 2ND DEGREE - DOMESTIC VIOLENCE 508.020 13161 13A',
#        'ROBBERY - 2ND DEGREE 515.030 12003 120',
#        'POSSESSION OF HANDGUN BY CONVICTED FELON 527.040 52197 520',
#        'MENACING 508.050 00803 13C',
#        'VIOLATION OF KENTUCKY EPO/DVO 403.763 02763 90F',
#        'TBUT OR DISP BICYCLES 514.030 24120 23H',
#        'WANTON ENDANGERMENT-2ND DEGREE 508.070 00441 13C',
#        'THEFT OF PROP MISLAID OR DELIVER BY IMISTAKE 514.050(1) 23472 23H',
#        'ASSAULT - 2ND DEGREE 508.020 13160 13A',
#        'TBUT OR DISP CONTENTS FROM VEH $1,000 < $10,000 514.030 24142 23F',
#        'CRIMINAL TRESPASSING-3RD DEGREE 511.080 02617 90J',
#        'LEAVING SCENE OF ACCIDENT/FAILURE TO RENDER AID OR ASSISTANC189.580(1)(a) 00569 999',
#        'TRAF IN CONT SUBST 1ST DEG 1ST OFFENSE (>= 2 GMS METH 218A.1412 42365 35A',
#        'TRAF CONT SUB-1ST DEG 1ST OFF (>= 4 GRAMS COCAINE) 218A.1412 42368 35A',
#        'POSS CONT SUB-1ST DEGREE-1ST OFFENSE-COCAINE 218A.1415 42203 35A',
#        'TRAF CONT SUB-1ST DEG 1ST OFF (< 4 GRAMS COCAINE) 218A.1412 42370 35A',
#        'TAMPERING WITH PHYSICAL EVIDENCE 524.100 50230 90Z',
#        'RECEIVING STOLEN PROPERTY $10,000 OR MORE 514.110(3)(c) 28014 280',
#        'PROMOTING A SEXUAL PERFORMANCE BY A MINOR U/18 531.320(2A) 37230 370',
#        'CRIMINAL TRESPASS-1ST DEGREE 511.060 02616 90J',
#        'DISCHARGE FIREARM/OTHER DEVICE ACROSS PUBLIC ROAD 150.360(4) 09061 90Z',
#        'UNLAWFUL IMPRISONMENT-2ND DEGREE 509.030 02606 100',
#        'POSS CONT SUB-1ST DEGREE-1ST OFFENSE-DRUG UNSPECIFIED 218A.1415 42201 35A',
#        'ASSAULT, 4TH DEGREE DATING VIOLENCE (MINOR INJURY) 508.030 00788 13B',
#        'TBUT OR DISP CONTENTS FROM VEH $500 < $1,000 514.030 24141 23F',
#        'ASSAULT-3RD DEGREE-POLICE/PROBATION OFFICER-IDENTIFY WEAPON 508.025 13113 13B',
#        'ANY NON CRIMINAL CHARGE NOT COVERED BY THESE CODES ***.*** 03013 90Z',
#        'STRANGULATION 1ST DEGREE 508.170 13225 13A',
#        'TRAF IN MARIJUANA-LESS THAN 8 OZ-1ST OFFENSE 218A.1421(2) 42301 35A',
#        'CRIMINAL MISCHIEF - RESIDENTIAL RENTAL PROPERTY 3RD 512.020 01420 290',
#        'JUSTIFIABLE HOMICIDE ***.*** 09160 09C',
#        'ASSAULT, 4TH DEGREE DATING VIOLENCE (NO VISIBLE INJURY) 508.030 00786 13B',
#        'STRANGULATION 1ST DEGREE (NON-DOMESTIC VIOLENCE) 508.170 13223 13A',
#        'TBUT OR DISP COIN MACHINE 514.030 24130 23E',
#        'TRAF IN MARIJUANA-8 OZ TO < 5 LBS-1ST OFFENSE 218A.1421(3) 42311 35A',
#        'POSS CONTROLLED SUB 1ST DEGREE 2ND OFF (METHAMPHETAMINE) 218A.1415 42187 35A',
#        'OBSCURING THE IDENTITY OF A MACHINE U/$10000 514.120 23237 26A',
#        'THEFT OF PROP MISLAID OR DELIVER BY IMISTAKE $1000 < $10,000514.050(1)(b) 23476 23H',
#        'ENDANGERING THE WELFARE OF A MINOR 530.060 02002 90F',
#        'UNLAWFUL TRANSACTION W/MINOR - 2ND DEGREE 530.065 38152 90Z',
#        'ASSAULT 3RD - PEACE OFFICER - NON COMMUNICABLE BODILY FLUID 508.025 13126 13A',
#        'TBUT OR DISP AUTO 514.030 24110 240',
#        'RECEIVING STOLEN PROPERTY (FIREARM) 514.110 28020 280',
#        'CRIMINAL MISCHIEF - RESIDENTIAL RENTAL PROPERTY 2ND 512.020 01418 290',
#        'POSSESSION OF SYNTHETIC DRUGS 1ST OFFENSE 218.A.1430 42395 35A',
#        'TRAFF IN CONT SUB, 1ST OFF(CARFENTANIL OR FENTANYL DERIVITES218A.1412 42472 35A',
#        'ATT MURDER OF FIRST RESPONDER (PEACE OFFICER) 507.070 09174A 09A',
#        'DISORDERLY CONDUCT - 2ND DEGREE 525.060 02371 90C',
#        'POSS OF OPEN ALCOHOLIC BEVERAGE CONTAINER IN MTR VEH PROHIBI189.530(2) 00470 90E',
#        'WANTON ENDANGERMENT-1ST DEGREE-POLICE OFFICER 508.060 13221 13A',
#        'OPER MTR VEH UNDER INFL ALC .08 (189A010(1A) - 1ST (AGG CIR)189A.010(5A) 03112 90D',
#        'INTIMIDATING A PARTICIPANT IN LEGAL PROCESS 524.040 51201 13C',
#        'UNLAWFULLY PROV/PERMIT MINOR TO POSSESS HANDGUN 527.110 52203 520',
#        'ABUSE OF CORPSE 525.120 02600 90Z',
#        'DIST OF SEXUALLY EXPLICIT IMAGES W/OUT CONSENT 1ST OFFENSE 531.020 01765 370',
#        'LEAV SCENE OF ACCIDENT/FAIL TO RNDR AID/ASSIST W/DEATH OR SJ189.580(1)(A) 00572 90Z',
#        'POSSESSION OF FIREARM BY CONVICTED FELON 527.040 52196 520',
#        'TBUT OR DISP ALL OTHERS $500 < $1,000 514.030 24096E 270',
#        'THEFT OF SERVICES 514.060(4) 23481 23H',
#        'POSS CONT SUB-1ST DEGREE-1ST OFFENSE-HEROIN 218A.1415 42205 35A',
#        'ASSAULT 3RD - HEALTHCARE PROVIDER 311.821(1)(A)(3) 13130 13A',
#        'VIOLATION OF COURT ORDER 215.570 (2) 60289 90Z',
#        'TBUT PARTS FROM VEHICLE 514.030 24240 23G',
#        'CRIMINAL POSSESSION OF FORGED INSTRUMENT-3RD DEGREE 516.070 01006 250',
#        'STALKING-1ST DEGREE 508.140 13242 13C',
#        'INDECENT EXPOSURE - 2ND DEGREE 510.150 01754 90Z',
#        'UNLAW ACT RELATED TO ACQUIRING METALS-INJURY TO PROP <$3000 512.090 02581 290',
#        'POSS CONT SUB 1ST DEGREE FENTANYL 218A.1415 42490 35a',
#        'PRESCRIPTION CONT SUB NOT IN ORIGINAL CONTAINER-1ST OFFENSE 218A.210 42055 35A',
#        'POSS CONT SUB 3RD DEGREE DRUG UNSPECIFIED 217A.1417 42263 35A',
#        'ASSAULT 4TH DEGREE (DOMESTIC 3RD OR > WITHIN 5 YEARS 508.032 00790 13B',
#        'FLEEING OR EVADING POLICE, 3RD DEGREE 520.105 02395 90Z',
#        'TBUT OR DISP ALL OTHERS 514.030 24095E 270',
#        'FRAUD USE OF CREDIT CARD AFTER RPT LOST/STOLEN < $500 434.655(2) 71211 26A',
#        'POSSESSION OF BURGLARY TOOLS 511.050 02662 90Z',
#        'FALSE REPORT WHICH GENERATES AN EMERGENCY RESPONSE 519.040(2)(B) 02721 90Z',
#        'CARRYING A CONCEALED DEADLY WEAPON 527.020 01501 520',
#        'FLEEING OR EVADING POLICE, 2ND DEGREE (ON FOOT) 520.100 00284 90Z',
#        'CRIMINAL ABUSE-1ST DEGREE 508.100 13230 13A',
#        'TBUT OR DISP CONTROLLED SUB < $10,000 514.030 23913 23H',
#        'ARSON - 2ND DEGREE 513.030 20004 200',
#        'CUSTODIAL INTERFERENCE-FELONY 509.070 10210 100',
#        'OPER MTR VEH UNDER INFLUENCE ALC .08 (189A010(1A) - 1ST 189A.010(5A) 03110 90D',
#        'VIOLATION OF IPO 456.180 02770 90F',
#        'UNLAWFUL IMPRISONMENT-1ST DEGREE 509.020 10201 100',
#        'VIOLATION OF CONDITIONS OF RELEASE 431.064 01152 90Z',
#        'VIOLATION OF FOREIGN EPO/DVO 403.7529 02762 90F',
#        'ARSON - 1ST DEGREE 513.020 20003 200',
#        'CRIMINAL ABUSE 1ST DEGREE - CHILD 12 OR UNDER 508.100(1)(c) 13239 13A',
#        'TRAFFICKING IN SYNTHETIC DRUGS - 1ST OFFENSE 218.A.1430 42391 35A',
#        'POSS CONT SUB-1ST DEGREE-1ST OFFENSE-LSD 218A.1415 42207 35A',
#        'SEXUAL ABUSE - 3RD DEGREE 510.130 01709 11D',
#        'ARSON - 3RD DEGREE 513.040 20005 200',
#        'OPER MTR VEH UNDER INFL ALC .08 (189A.010(1E)2ND 189A.010(5A) 03148 90D',
#        'STRANGULATION 2ND DEGREE (DOMESTIC VIOLENCE RELATED) 508.175 13229 13A',
#        'TRAF IN CONT SUBST 1ST DEG 1ST OFFENSE (< 2 GMS METH 218A.1412 42366 35A',
#        'DISPLAY OF ILLEGAL/ALTERED REGISTRATION PLATE 186.170 05133 90Z',
#        'TERRORISTIC THREATENING 1ST DEGREE 508.075 00820 13C',
#        'CRIMINAL MISCHIEF - RESIDENTIAL RENTAL PROPERTY 1ST 512.020 01416 290',
#        'TBUT OR DISP ALL OTHERS $1,000 < $10,000 514.030 24097E 270',
#        'FIREARMS DISCHARGE PROHIBITED LMCO 135.03 80100 999',
#        'FAILURE OF OWNER TO MAINTAIN REQUIRED INS/SECURITY 1ST OFF 304.39-080 00480 90Z',
#        'TRAF IN MARIJUANA-LESS THAN 8 OZ-2ND OR > OFFENSE 218A.1421(2) 42302 35A',
#        'POSS CONTROLLED SUB 1ST DEGREE 3RD > (METHAMPHETAMINE) 218A.1415 42188 35A',
#        'TRAF CONT SUB-1ST DEG 1ST OFF (> OR = 10 DU OPIATES) 218A.1412 42372 35A',
#        'TRAF CONT SUB-1ST DEG -1ST OFFN- (>= 10 DU DRUG UNSPECIFIED)218A.1412 42381 35A',
#        'TICS 1ST OFFENSE FENTANYL 218A.1412M 42492 35A',
#        'THEFT OF RETAIL MERCHANDISE FOR RESALE 506.120 23430 90Z',
#        'INVOLUNTARY HOSPITALIZATION OF MENTALLY ILL - 60/360 DAYS 202A.051 03004 90Z',
#        'POSS CONT SUB-2ND DEGREE- HALLUCINOGEN 218A.1416 42243 35A',
#        'DIST OF MATTER PORTRAYING SEX PERF BY MINOR O/12, UNDER 18 531.340 37292 370',
#        'MISUSE OF ELECTRONIC INFO-AUTOMATED BANKING DEVICE, ETC 434.685(1) 21221 26B',
#        'TBUT OR DISP POCKETPICKING $500 < $1,000 514.030 24211 23A',
#        'POSS A CONT SUB 218A.1404(2) 42022 35A',
#        'ASSAULT 3RD - PEACE OFFICER - COMMUNICABLE BODILY FLUID 508.025 13128 13A',
#        'TRAFF IN CONT SUB, 1ST DEGREE, 1ST OFF - (< 10D.U.DRUGUNSPE)218A.1412 42382 35A',
#        'TBUT OR DISP POCKETPICKING $1,000 < $10,000 514.030 24212 23A',
#        'CARJACKING 515.040 24105 120',
#        'POSS CONT SUB-2ND DEGREE-DRUG UNSPECIFIED 218A.1416 42245 35A',
#        'FLEEING OR EVADING POLICE 2ND DEGREE (MOTOR VEHICLE) 520.100 00276 90Z',
#        'CRIMINAL ABUSE-2ND DEGREE-CHILD 12 OR UNDER 508.110(1C) 13241 13A',
#        'SODOMY - 1ST DEGREE 510.070 11180 11B',
#        'DRUG PARAPHERNALIA - DELIVER/MANUFACTURE 218A.500(3) 42082 35B',
#        'FORGERY - 1ST DEGREE 516.020 25018 250',
#        'KIDNAPPING-ADULT 509.040 10060 100',
#        'THEFT OF SERVICES $1,000 TO < $10,000 514.060(4)(b) 23485 23H',
#        'MISREPRESENTING MILITARY STATUS                             434.444             21207                    26A',
#        'POSS/MANUFACTURE/ETC CONTERFEIT SUB- 218A.140(2) 42124 35A',
#        'AGG TRAFF IN CONT SUB (>OR=28 GRAMS (FENTANYL) 218A.1412 42478 35A',
#        'TRAF CONT SUB 2ND DEG 1ST OFFN (>= 10 DU HALLUCINOGEN 218A.1413(1A) 42447 35A',
#        'TRAF IN MARIJUANA-> 5 LBS-1ST OFFENSE 218A.1421(4) 42321 35A',
#        'VIDEO VOYUERISM 531.100 01740 90H',
#        'TRAFF IN CONTROLLED SUBSTANCE 1ST OFFENSE (HEROIN) 218A.1412 42466 35A',
#        'TBUT OR DISP ALL OTHERS $10,000,000 OR MORE 514.030 24100 23H',
#        'TBUT OR DISP AUTO $1,000,000 < $10,000,000 514.030 24114 240',
#        'ATT/PREVENT AUTH PEACE OFFICER FROM CONCEALED CARRY 1ST OFF 237.137 52111 90Z',
#        'VOYEURISM 531.090 01730 90H',
#        'TBUT OR DISP BICYCLES $500 < $1,000 514.030 24121 23H',
#        'ASSAULT - 1ST DEGREE - DOMESTIC VIOLENCE 508.010 13151 13A',
#        'THEFT OF MEDICAL RECORDS 2ND OR > 218A.322 41850 90Z',
#        'THEFT BY EXTORTION 514.080(3) 23400 210',
#        'VIOLATING GRAVES 525.115 01413 290',
#        'UNLAWFUL ACCESS TO COMPUTER - 2ND DEGREE 434.850 51261 90Z',
#        'FLEEING OR EVADING POLICE, 1ST DEGREE 520.095 02393 90Z',
#        'TRAF IN SYNTHETIC DRUGS 2ND OR SUBSEQUENT OFFENSE 218.A.1430 42393 35A',
#        'TBUT OR DISP PURSESNATCHING 514.030 24220 23B',
#        'RESISTING ARREST 520.090 02404 90Z',
#        'POSS CONT SUB-1ST DEGREE-1ST OFFENSE-OPIATES 218A.1415 42209 35A',
#        'USE SCAN/DEVICE/REENCODER ACCESS/TRANSFER INFO OF CC 1ST OF434.675 21360 90Z',
#        'DIST OF SEXUALLY EXPL IIMAGES W/OUT CONSENT FOR PROFIT 1ST 531.020 01770 370',
#        'THEFT BY EXTORTION $1,000 < $10,000 514.080(3)(b) 23404 210',
#        'NO/EXPIRED OTHER STATE REGISTRATION RECEIPT OR PLATE 186.140 05131 90Z',
#        'STALKING-2ND DEGREE 508.150 13243 13C',
#        'UNLAWFUL POSSESSION OF WEAPON ON SCHOOL PROPERTY 527.070 52204 520',
#        'TBUT OR DISP CONTENTS FROM VEH $10,000 < $1,000,000 514.030 24143 23F',
#        'FILING FALSE REPORTS UNDER KRS 304 SUBTITLE 37 304.37-010 00524 26A',
#        'GIVING OFFICER FALSE IDENTIFYING INFORMATION 523.110(1) 02708 90Z',
#        'THEFT OF A LEGEND DRUG 1ST OFFENSE OR VALUE < THAN $300 217.181 41990 23H',
#        'FORGERY - 2ND DEGREE 516.030 25019 250',
#        'MISUSE OF COMPUTER INFORMATION 434.855 51270 90Z',
#        'MURDER - DOMESTIC VIOLENCE 507.020 09151 09A',
#        'TRAF CONT SUB-2ND DEGREE-1ST OFF ( >= 10 DU CODEINE) 218A.1413(1A) 42436 35A',
#        'TRAF CONT SUB-2ND DEGREE-1ST OFF (< 10 DU CODEINE) 218A.1413(1A) 42437 35A',
#        'RECEIVING STOLEN PROPERTY 514.110(3) 28008 280',
#        'POSSESSION OF A FORGERY DEVICE-IDENTIFY 516.090 25080 250',
#        'DISORDERLY CONDUCT - 1ST OFFENSE 525.055 02370 90C',
#        'TRAF IN CONT SUB-1ST OFFENSE 218A.1404(1) 42015 35A',
#        'TRAF CONT SUB-1ST DEG-2ND OR > OFF (>= 4 GRAMS COCAINE 218A.1412 42369 35A',
#        'TBUT OR DISP POCKETPICKING 514.030 24210 23A',
#        'SEXUAL MISCONDUCT 510.140 01710 90Z',
#        'POSS CONT SUB-1ST DEGREE-2ND OFFENSE-HEROIN 218A.1415 42195 35A',
#        'CRIMINAL MISCHIEF-3RD DEGREE 512.040 01403 290',
#        'THEFT-RECEIPT OF STOLEN CREDIT/DEBIT CARD-1 CARD 434.580 71263 23H',
#        'UNAUTHORIZED SIGNATURE ON A CREDIT CARD 434.640 71268 26B',
#        'THEFT BY DECEPTION INCLUDING COLD CHECKS $500 < $1,000 514.040(8)(a) 71285E 270',
#        'OPER MTR VEH UNDER INFL ALC .08 (189A010(1D) - 1ST 189A.010(5A) 03122 90D',
#        'ENGAGING IN ORGANIZED CRIME-CRIMINAL SYNDICATE 506.120 70240 90Z',
#        'USING RESTRICTED AMMO DURING A FELONY (NO SHOTS) 527.080(2)(A) 02549 520',
#        'OBSTRUCTING GOVERNMENTAL OPERATIONS 519.020 02657 13C',
#        'CRUELTY TO ANIMALS - 2ND DEGREE 525.130 02625 720',
#        'POSS CONT SUB-1ST DEGREE-3RD OR > OFFENSE-HEROIN 218A.1415 42196 35A',
#        'POSSESSION OF DEFACED FIREARM 527.050 01504 520',
#        'OPER MTR VEH U/INFL ALC .08 (189A.010(1A) 4TH OR > 189A.010(5D) 03176 90D',
#        'DRIVING DUI SUSPENDED LICENSE-2ND OFFENSE 189A.090(2B) 02629 90D',
#        'SODOMY - 1ST DEGREE - VICTIM U/12 YEARS OF AGE 510.070 11186 11B',
#        'KIDNAPPING-WITH SERIOUS PHYSICAL INJURY 509.040 10071 100',
#        'OPER MTR VEHICLE U/INFL SUBST (189A.010(1C) - 1ST (AGG CIR) 189A.010(5A) 03120 90D',
#        'OPER MTR VEH UNDER INFL ALC .08 (189A.010(1E) 3RD (AGG CIR) 189A.010(5C) 03172 90D',
#        'OBSCURING THE IDENTITY OF A MACHINE U/$500 514.120 23236 26A',
#        'POSS CONT SUB-1ST DEGREE-2ND OFFENSE-COCAINE 218A.1415 42193 35A',
#        'LOITERING 525.090 02730 90B',
#        'OPER MTR VEH UNDER INFL ALC .08 (189A010(1B) - 1ST 189A.010(5A) 03114 90D',
#        'KNOWINGLY ABUSE/NEGLECT OF ADULT BY PERSON 209.990(2) 02031 13B',
#        'FLEEING OR EVADING POLICE, 2ND DEGREE 520.100 02394 90Z',
#        'UNLAWFUL CAMPING - 1ST OFFENSE 511.110 02750 90J',
#        'POSS CONT SUB-1ST DEGREE-2ND OFFENSE-DRUG UNSPECIFIED 218A.1415 42191 35A',
#        'TBUT OR DISP AUTO $10,000,000 OR MORE 514.030 24115 240',
#        'ALCOHOL INTOXICATION IN A PUBLIC PLACE-1ST & 2ND OFFENSES 222.202(1) 02304 90E',
#        'MANSLAUGHTER-2ND DEGREE 507.040 09202 09B',
#        'TRAF IN CONT SUBST 1ST DEG 2ND OR > OFFENSE <= 2 GMS METH 218A.1412 42364 35A',
#        'TRAFF IN CONTROLLED SUBST 2ND OR > OFF (HEROIN) 218A.1412 42468 35A',
#        'CRIMINAL MISCHIEF 2ND DEG- RESTITUTION/REPAIR 512.030(b) 29205 290',
#        'FAILURE TO APPEAR, CITATION FOR MISDEMEANOR 431.015 01150 90Z',
#        'TBUT OR DISP PURSESNATCHING $1,000 < $10,000 514.030 24222 23B',
#        'ASSAULT - 2ND DEGREE - POLICE OFFICER 508.020 13162 13A',
#        'ASSAULT - 1ST DEGREE - POLICE OFFICER 508.010 13152 13A',
#        'RAPE - 2ND DEGREE (MENTALLY INCAPACITATED) 510.050 11161 11A',
#        'TRF CON SUB 2ND DEG 1ST OFN (< 20 DU DRUG UNSPEC SCH III 218A.1412 42457 35A',
#        'KIDNAPPING-MINOR 509.040 10050 100',
#        'UNAUTHORIZED USE OF MOTOR VEHICLE - 2ND OR > OFFENSE 514.100 00702 240',
#        'THEFT OF PROP MISLAID OR DELIVER BY IMISTAKE $10,000 OR > 514.050(1)(c) 23478 23H',
#        'DISTRIBUTION OF OBSCENE MATTER >1 UNIT OF MATTER 531.020 01714 370',
#        'AGG TRAFF IN CONTROLLED SUBST (> OR = 100 GMS HEROIN) 218A.1412 42470 35A',
#        'USING RESTRICTED AMMO DURING A FELONY (SHOTS FIRED, NO INJUR527.080(2)(B) 02550 520',
#        'OPER MTR VEH UNDER INFL ALC .08 (189A010(1C) - 1ST 189A.010(5A) 03118 90D',
#        'DISPENSE/PRESCRIBE/ADMINISTER CONT SUB-1ST OFFENSE 218A.1404(3) 42025 35A',
#        'POSSESSION OF STOLEN MAIL MATTER 514.150 28040 280',
#        'OBSCURING THE IDENTITY OF A MACHINE $10000 OR MORE 514.120 23238 26A',
#        'TBUT OR DISP GASOLINE 514.030 24180 23H',
#        'CRIMINAL MISCHIEF 1ST DEG- RESTITUTION/REPAIR - 1ST OFF 512.020(b) 29203 290',
#        'ESCAPE-3RD DEGREE 520.040 02634 90Z',
#        'FRAUD USE OF CREDIT CARD AFTER RPT LOST/STOLEN $500 < $1000 434.655(2)(a) 71213 26A',
#        'UNLAWFUL ACCESS TO COMPUTER - 3RD DEGREE 434.851 51262 90Z',
#        'SEXUAL CRIMES AGAINST ANIMALS 525.130 02566 720',
#        'ASSAULT 3RD DEGREE (EMS,FIRE, RESCUE SQUAD) 508.025 13120 13B',
#        'TRAF CONT SUB-2ND DEG 2ND OR > OFFN (>= 10 DU HALLUCINOGEN 218A.1413(1A) 42448 35A',
#        'ILLEGAL POSSESSION OF LEGEND DRUG 217.182(7) 42009 35A',
#        'OBSTRUCTIONS/INTERFERENCE WITH AN OFFICER 150.090 09084 90Z',
#        'RETALIATING AGAINST PARTICIPANT IN LEGAL PROCESS 524.055 51202 13C',
#        'BRIBERY OF A PUBLIC SERVANT 521.020 51200 510',
#        'AGG TRAF IN CONT SUB(>OR=10 GR CARFENTANIL OR FENT OR DERIV 218A.1412 42476 35A',
#        'FORGERY-3RD DEGREE 516.040 25023 250',
#        'POSS OF CONT SUBSTANCE - 1ST DEGREE - 1ST OFFENSE (DATE RAPE218A.1415 42213 35A',
#        'VEHICULAR HOMICIDE WHEN UNDER THE INFLUENCE OF ALCOHOL 507.060 09148 09B',
#        'UNAUTHORIZED PROCUREMENT OF CONT SUB 218A.140 42032 90Z',
#        'TICS 2ND OFFENSE FENTANYL 218A.1412 42494 35A',
#        'TRAFF IN CONT SUB, 2ND OFF(CARFENTANIL OR FENTANYL DERIVITES218A.1412 42474 35A',
#        'TRAF IN MARIJUANA-8 OZ TO < 5 LBS-2ND OR > OFFENSE 218A.1421(3) 42312 35A',
#        'POSS CONT SUB-2ND DEGREE-CODEINE 218A.1416 42246 35A',
#        'CULTIVATE IN MARIJUANA-5 PLANTS OR >-1ST OFFENSE 218A.1423(2) 42341 35A',
#        'OBSTRUCTING EMERGENCY RESPONDER VIOLATIONS 1ST OFFENSE 525.015 02410 90Z',
#        'WANTON ENDANGERMENT-2ND DEGREE-POLICE OFFICER 508.070 00444 13C',
#        'SERVING ARREST WARRANT OR CRIMINAL SUMMONS ***.*** 55555 90Z',
#        'OPER MTR VEH UNDER INFL ALC .08 (189A010(1E) - 1ST 189A.010(5A) 03126 90D',
#        'FAILURE TO COMPLY W/SEX OFFENDER REGISTRATION-2ND > OFFENSE 17.510(11) 01681 90Z',
#        'TRAF CONT SUB-1ST DEG 2ND OR > OFF (>= 10 DU OPIATES) 218A.1412 42373 35A',
#        'INTERFERING WITH COMMUNICATIONS 438.210 02650 90Z',
#        'VIOLATION OF STALKING RESTRAINING ORDER 508.155 02764 90Z',
#        'TRAF CONT SUB WITHIN 1000 YRDS OF SCHOOL 218A.1411 42091 35A',
#        'TRAF N CONT SUB 3RD DEG,1ST OFF(>OR=20 BUT<OR=120 DU DRUG UN218A.1412 42575 35A',
#        'ANY MISDEMEANOR CHARGE NOT COVERED BY THESE CODES 999.000 02689 90Z',
#        'TRAF IN CONT SUB-2ND OR > OFFENSE 218A.1404(1) 42016 35A',
#        'TRAF CONT SUB-1ST DEG 2ND OR > OFF (< 10 DU OPIATES) 218A.1412 42375 35A',
#        'POSS HANDGUN BY MINOR 2ND OR > 527.100 52205 520',
#        'TRAFFICKING IN STOLEN IDENTITIES 514.170 23311 250',
#        'FRAUD USE OF CREDIT CARD AFTER RPT LOST/STOLEN $1000<$10,000434.655(2)(b) 71215 26A',
#        'LOTTERY ALTER/FORGE/UTTERS/PASSES/CONTERFEITS TICKET 154A.990(2) 39409 250',
#        'VIOLATION OF FOREIGN IPO 456.120 02774 90F',
#        'CRIMINAL ABUSE-3RD DEGREE 508.120 00810 13B',
#        'PERSISTENT FELONY POSSESSION OF FIREARM 527.040((2)(b) 52190 520',
#        'THEFT BY EXTORTION $10,000 OR MORE 514.080(3)(c) 23406 210',
#        'TBUT OR DISP FARM EQUIP $10,000 < $1,000,000 514.030 24153 23H',
#        'THEFT BY EXTORTION $500 < $1,000 514.080(3) (a) 23402 210',
#        'UNLAWFUL TRANSACTION W/MINOR 1ST DEG/ILL CONT SUB U/16 YOA 530.064(1)(B) 38113 90Z',
#        'CRIMINAL MISCHIEF - RESIDENTIAL RENTAL PROPERTY 3RD 512.040 01420 290',
#        'TRAF CONT SUB-3RD DEG 1ST OFF (< 20 DU DRUG UNSPECIFIED) 218A.1414 42572 35A',
#        'PUBLIC INTOXICATION CONTROLLED SUBSTANCE (EXCLUDES ALCOHOL) 525.100 02303 90E',
#        'STRANGULATION 2ND DEGREE (NON-DOMESTIC VIOLENCE) 508.175 13228 13A',
#        'TRF CON SUB 1ST DEG 2ND> OFN (< 10 DU DRUG UNSPEC SCH I & II218A.1412 42383 35A',
#        'POSS CONT SUB-1ST DEGREE-1ST OFFENSE-PCP 218A.1415 42211 35A',
#        'ABATEMENT OF NUISANCES CHR 211.210 60270 90Z',
#        'THEFT OF SERVICES $10,000 OR MORE 514.060(4)(c) 23487 23H',
#        'OPER MTR VEH UNDER INFL ALC .08 (189A.010(1A)- 3RD (AGG CIR)189A.010(5C) 03156 90D',
#        'TRAF IN CONT SUBST 1ST DEG 2ND OR > OFFENSE < 2 GRAMS METH 218A.1412 42367 35A',
#        'WEARING OF MASKS JCO 130.01 88117 999',
#        'OPER MTR VEH UNDER INFL ALC .08 (189A.010(1D)2ND 189A.010(5A) 03144 90D',
#        'SEXUAL ABUSE - 2ND DEGREE 510.120 11222 11D',
#        'DISTRIBUTION OF OBSCENE MATTER - 1 UNIT OF MATTER 531.020 01713 370',
#        'SERVING WARRANT (FOR OTHER POLICE AGENCY) ***.*** 02900 90Z',
#        'POSS CONT SUB-2ND DEGREE--AMPHETAMINE 218A.1416 42241 35A',
#        'AUTO THEFT PENDING ADDITIONAL INFORMATION 999.999 78787 999',
#        'IMPERSONATING A PEACE OFFICER 519.055 02632 26C',
#        'OPER BOAT/WATERCRAFT WHILE INTOXICATED OR U/INFLUENCE, 1ST 235.240 05985 90D',
#        'CRIMINAL LITTERING 512.070 02621 90Z',
#        'TRAF CONT SUB-1ST DEG 1ST OFF (< 10 DU OPIATES) 218A.1412 42374 35A',
#        'DECEPTIVE BUSINESS PRACTICES 517.020 01101 26A',
#        'FALSELY REPORTING AN INCIDENT 519.040 02640 90Z',
#        'EAVESDROPPING 526.020 57040 90Z',
#        'USE SCAN DEVICE/REENCODER ACCESS/TRANS INFO OF CC 2ND> OFF 434.675 21361 90Z',
#        'MANUFACTURING METHAMPHETAMINE 1ST OFFENSE 218A.1432 42299 35A',
#        'FLEEING OR EVADING POLICE, 1ST DEGREE (MOTOR VEHICLE) 520.095 00283 90Z',
#        'IMPERSONATING A PUBLIC SERVANT 519.050 02646 26C',
#        'CULTIVATE IN MARIJUANA-< 5 PLANTS-1ST OFFENSE 218A.1423(2) 42348 35A',
#        'DEPENDENCY ACTION UNIFIED JUVENILE CODE 620.070 02813 90Z',
#        'CRIMINAL MISCHIEF - RESIDENTIAL RENTAL PROPERTY 2ND 512.030 01418 290',
#        'POSS CONT SUB-1ST DEGREE-3RD OR > OFFENSE-DRUG UNSPECIFIED 218A.1415 42192 35A',
#        'WANTON ENDANGERMENT 1ST - DISCHARGE OF FIREARM 508.060 13204 13C',
#        'CRIMINAL POSS OF A FORGED PERSCRIPTION, 1ST OFFENSE 218A.284 25063 250',
#        'TRAF CONT SUB-1ST DEG 2ND OR > OFFEN (>= 10 DU DRUG UNSPECIF218A.1412 42380 35A',
#        'UNLAWFUL ACCESS TO COMPUTER - 4TH DEGREE 434.853 51263 90Z',
#        'POSS CONT UB, 1ST DEG, 1ST OFF HYDROCODONE 218A.1415 42218 35A',
#        'TBUT OR DISP FROM BUILDING $10,000,000 OR MORE 514.030 24165 23D',
#        'ABANDONMENT OF MINOR 530.040 38200 90F',
#        'INCEST - WITH PERSON LESS THAN 12 YEARS OLD 530.020 36057 36A',
#        'TBUT OR DISP ALL OTHERS $1,000,000 < $10,000,000 514.030 24099 23H',
#        'NEGLECT ACTION UNIFIED JUVENILE CODE 620.070 02814 90Z',
#        'SODOMY - 2ND DEGREE 510.080 11202 11B',
#        'CRIMINAL ABUSE-THIRD DEGREE-CHILD 12 ORUNDER 508.120(1C) 00811 13B',
#        'FALSE REPORT AN INCIDENT TO LAW ENFORCEMENT 519.040(2)(A) 02722 90Z',
#        'THEFT-RECEIPT OF STOLEN CREDIT/DEBIT CARD-2 OR MORE CARDS 434.580 71264 23H',
#        'DETENTION AND ARREST OF SHOPLIFTING SUSPECT 433.236 57210 23C',
#        'DISTRIBUTION OBSCENE MATTER TO MINORS - 1ST OFFENSE 531.030 37201 370',
#        'ILLEGAL POSSESSION OF PRESCRIPTION BLANKS - 1ST OFFENSE 218A.286 42050 280',
#        'OFFICIAL MISCONDUCT-1ST DEGREE 522.020 02658 90Z',
#        'MISSING PERSONS ***.*** 03011 90Z',
#        'OPER MTR VEH UNDER INFL ALC .08 (189A010(1C) - 1ST (AGG CIR)189A.010(5A) 03120 90D',
#        'RAPE - 1ST DEGREE - INCAP OF CONST/PHYS HELPLESS W/SERIOUS P510.040 10995 11A',
#        'INDECENT EXPOSURE - 1ST DEGREE - 2ND OFFENSE 510.148 01751 90Z',
#        'PROH POSS LOADED GUN IN RM WHERE ALC BEV SOLD 1ST OFF 244.996 02259 90G',
#        'TRAF CONT SUB-1ST DEG-2ND OR > OFF (< 4 GRAMS COCAINE 218A.1412 42371 35A',
#        'RAPE - 2ND DEGREE (INTELLECTUAL DISABILITY) 510.050 11168 11A',
#        'PROMOTING CONTRABAND-1ST DEGREE 520.050 49031 90Z',
#        'PRESCRIPTION CONT SUB NOT IN ORIGINAL CONTAINER-2ND OR >OFF 218A.210 42056 90Z',
#        'TBUT OR DISP PURSESNATCHING $500 < $1,000 514.030 24221 23B',
#        'RAPE-2ND DEGREE-NO FORCE 510.050 11162 36B',
#        'FRAUDULENT TELEGRAPH OR TELEPHONE TRANSMISSION 438.220 01118 26A',
#        'TBUT OR DISP SHOPLIFTING CLASS-A, 3 OR MORE IN 5 YEARS 514.030 24236 23C',
#        'CRIMINAL POSS OF A FORGED PERSCRIPTION, 2ND OR > OFFENSE 218A.284 25064 250',
#        'TBUT OR DISP GASOLINE $500 < $1,000 514.030 24181 23H',
#        'TERR THREAT 2ND DEG SUB CONDUCT TO PREPARE/CARRY OUT ACT 508.078(5) 00824 13C',
#        'STRANGULATION 2ND DEGREE 508.175 13227 13A',
#        'FAILURE OF OWNER TO MAINTAIN REQUIRED INS/SECURITY 2ND OFF 304.39-080 00481 90Z',
#        'OPER MTR VEH UNDER INFL ALC .08 (189A010(1B) - 1ST (AGG CIR)189A.010(5A) 03116 90D',
#        'TBUT OR DISP GASOLINE $1,000 < $10,000 514.030 24182 23H',
#        'FAIL OF NON-OWNER/OPER TO MAINTAIN REQ INS/SECURITY 2ND OFF 304.99-060 00483 90Z',
#        'TRAFFICKING IN STOLEN VEHICLES OR VEHICLE PARTS 186A.325 50237 280',
#        'CONTEMPT OF COURT, LIBEL/SLANDER, RESISTANCE TO ORDER 432.280 02648 90Z',
#        'ILLEGAL DUMPING LOUISVILLE METRO ORDINANCE 131.22 88510 999',
#        'THEFT BY FAIL TO MAKE REQ DISP OF PROPERTY $500 < $1,000 514.070(4)(a) 23492 26A',
#        'CRIMINAL MISCHIEF 1ST DEGREE TAMPER KEY INFRA ASSETS 512.020 01415 290',
#        'FLEEING OR EVADING POLICE - 2ND DEGREE (ON FOOT) 520.100 00199 90Z',
#        'INTENTIONAL UNLAWFUL USE OF A TRACKING DEVICE 508.152(3) 00815 90Z',
#        'TBUT OR DISP ALL OTHERS $10,000 < $1,000,000 514.030 24098E 270',
#        'UNLAWFUL TRANSACTION W/MINOR - 3RD DEGREE 530.070 02013 90Z',
#        'CCDW BY PRIOR DEADLY WEAPON FELONY OFFENDER 527.020(10) 01506 520',
#        'ANY FELONY CHARGE NOT COVERED BY THESE CODES 999.999 91000 90Z',
#        'ANY VIOLATION CHARGE (EXCEPT TRAFFIC) NOT COVERED ***.*** 00700 90Z',
#        'THEFT OF LEGEND DRUG 2ND OR > OFFENSE OR VALUE > THAN $300 217.181 41991 23H',
#        'MURDER ATTEMPTED 507.020 09150A 13A',
#        'INCEST - FORCIBLE COMPULSION/INCAPABLE OF OR W/OUT CONSENT 530.020 36055 36A',
#        'PROC OR PROM USE OF MINOR BY ELECTRONIC MEANS 510.155(1) 10979 90Z',
#        'INTENTIOANAL OBSTRUCTION OF LAWFUL TAKING OF WILDLIFE, 1ST 150.710(1) 09144 90Z',
#        'TBUT OR DISP SHOPLIFTING $10,000 < $1,000,000 514.030 24233 23C',
#        'WANTON ABUSE/NEGLECT OF ADULT BY PERON 209.990(3) 02032 13B',
#        'SERVING BENCH WARRANT FOR COURT ***.*** 02906 90Z',
#        'TBUT OR DISP FARM EQUIP $500 < $1,000 514.030 24151 23H',
#        'TBUT OR DISP COIN MACHINE $500 < $1,000 514.030 24131 23E',
#        'HINDERING PROSECUTION OR APPREHENSION-2ND DEGREE 520.130 02644 90Z',
#        'DRIVING ON DUI SUSPENDED LICENSE-1ST OFFENSE 189A.090(2A) 02628 90D',
#        'OPER MTR VEH UNDER INFL ALC .08 (189A.010(1A) - 2ND 189A.010(5B) 03132 90D',
#        'PROC OR PROM USE OF MINOR BY ELECTRONIC MEANS 510.155(1) 10977 370',
#        nan,
#        'DIST OF MATTER PORTRAYING SEX PERF BY MINOR UNDER 12 1ST OFF531.340(3) 37287 370',
#        'CAUSING ANOTHER PERSON TO COMMIT SUICIDE 216.000 09203 90Z',
#        'OPER MTR VEH UNDER INFL ALC .08 (189A.010(1B) - 2ND 189A.010(5B) 03136 90D',
#        'TBUT OR DISP SHOPLIFTING $1,000,000 < $10,000,000 514.030 24234 23C',
#        'DISARMING A PEACE OFFICER 508.160 02633 13A',
#        'DEFACING A FIREARM 527.030 01502 520',
#        'TBUT PARTS FROM VEHICLE $10,000 < 1,000,000 514.030 24243 23G',
#        'FAILURE TO REPORT ACCIDENT IN EXCESS OF $500 235.250 06090 90Z',
#        'DESECRATION OF VENERATED OBJECTS-2ND DEGREE 525.110(1) 01404 290',
#        'TBUT OR DISP BICYCLES CLASS-A, 3 OR MORE IN 5 YEARS 514.030 24126 23H',
#        'TRAF CONT SUB-2ND DEG 1ST OFFN (< 10 DU AMPHETAMINE) 218A.1413(1A) 42551 35A',
#        'DOG FIGHTING VIOLATIONS 525.125 51006 720',
#        'TAMPERING W/PRISONER MONITORING DEVICE 519.070 02636 90Z',
#        'REPORT NUMBER NOT REQUIRED 999.999 33333 999',
#        'ILLEGAL SALE/GIVE ALCOHOL,DRY TERRITORY 2ND OFFENSE 242.230(1) 41032 90G',
#        'POSS/USE OF RADIO THAT SENDS/RECEIVES POLICE MESSAGES 432.570 02664 90Z',
#        'TRF CON SUB 2ND DEG 1ST OFN (>= 10 DU SCH I & II NON NARC) 218A.1412 42561 35A',
#        'WILLFULLY SETTING FIRE ON LAND NOT OWNED/CONTROLLED BY SELF 149.380(1) 09620 90Z',
#        'ACCIDENTAL DEATH (OTHER THAN DROWNING AND HUNTING) ***.*** 03002 90Z',
#        'INCEST 530.020 36050 36A',
#        'TORTURE DOG/CAT W/SERIOUS PHYS INJ OR DEATH 525.135(3) 02572 720',
#        'TBUT OR DISP COIN MACHINE $10,000 < $1,000,000 514.030 24133 23E',
#        'FLEEING OR EVADING POLICE, 1ST DEGREE (ON FOOT) 520.095 00282 90Z',
#        'ASSAULT ON SERVICE ANIMAL - 1ST DEGREE 525.200 13214 90Z',
#        'MURDER - POLICE OFFICER ATTEMPTED 507.020 09152A 13A',
#        'DIST OF SEXUALLY EXPLICIT IMAGES W/OUT CONSENT 2ND OR > 531.020 01767 370',
#        'TRAFFICKING IN A LEGEND DRUG, 1ST OFFENSE 217.182 41994 35A',
#        'VOLATILE SUBSTANCE ABUSE 217.900(2) 04800 35A',
#        'ASSAULT - 3RD DEGREE (OFFICER TRANSPORTING INMATES) 508.025 13124 13B',
#        'DIST OF MATTER PORTRAY SEX PERF BY MINOR O/12 U/18 1ST OFF 531.340(3) 37283 370',
#        'THEFT OF PROP MISLAID OR DELIVER BY IMISTAKE $10,0000 OR > 514.050(1)(c) 23478 23H',
#        'ALCOHOL INTOX IN PUBLIC PLACE-3RD OR > OFF W/12 MONTHS 222.202(1) 02301 90E',
#        'FRAUDULENT USE OF A CREDIT CARD 434.650(1)(B) 71200E 270',
#        'HUMAN TRAF - COMMERCIAL SEX ACTIVITY (VICTIM < 18 YOA) 529.100 40095 64A',
#        'MURDER - DOMESTIC VIOLENCE ATTEMPTED 507.020 09151A 13A',
#        'OPER MTR VEH UNDER INFL ALC .08 (189A010(1E) - 1ST (AGG CIR)189A.010(5A) 03128 90D',
#        'ASSAULT 3RD-DEPT SOCIAL SERVICES WORKER 508.025(1A3) 13115 13B',
#        'THEFT OF PRESCRIPTION BLANK FOR CONT SUB - 1ST OFFENSE 218A.286 42052 23H',
#        'ILLEGAL DUMPING LOUISVILLE METRO ORDINANCE GO 51.510 88510 999',
#        'TRAF CONT SUB-3RD DEG 2ND OR > OFFN (< 20 DU DRUG UNSPECIFI 218A.1414 42573 35A',
#        'TBUT OR DISP BICYCLES $1,000,000 < $10,000,000 514.030 24124 23H',
#        'RECKLESS ABUSE/NEGLECT OF ADULT BY PERSON 209.990(4) 02033 13B',
#        'RECKLESS HOMICIDE 507.050 09210 09B',
#        'KNOW/FRAUDULENTLY USE ID CARD OR ELECT CODE FOR BENEFITS 194A/B.505 21443 26A',
#        'ASSAULT - 3RD DEGREE (SCHOOL EMPLOYEE OR SCHOOL VOLUNTEER) 508.025 13123 13B',
#        'CRIMINAL ABUSE-1ST DEGREE-CHILD 12 OR UNDER 508.100(1C) 13231 13A',
#        'MENTALLY ILL & A DANGER TO SELF/OTHERS - ARREST OF PERSON 202A.041 03005 90Z',
#        'SODOMY - 1ST DEGREE - DOMESTIC VIOLENCE -W/SERIOUS PHYSICAL 510.070 11183 11B',
#        'PROMOTING PROSTITUTION 529.040 40190 40B',
#        'TRAF CONT SUB 2ND DEG 1ST OFFN (<10 DU HALLUCINOGEN 218A.1413(1A) 42449 35A',
#        'TBUT OR DISP COIN MACHINE $1,000 < $10,000 514.030 24132 23E',
#        'FORGERY OF A PERSCRIPTION FOR CONT. SUB, 1ST OFFENSE 217.208 25015 250',
#        'PHISHING 434.697 01665 90Z',
#        'LASER/VISION INTERF LIGHT DIRECT @ AIRCRAFT W DISRUPT TRAVEL183.887 05952 90Z',
#        'USING MINOR TO DISTRIBUTE OBSCENE MATERIAL - 1ST OFFENSE 531.040 37202 370',
#        'ESCAPE-2ND DEGREE-IDENTIFY FACILITY 520.030 49012 90Z',
#        'UNLAW ACT RELATED TO ACQUIRING METALS-INJURY TO PROP >$3000512.090 02583 290',
#        'TRESPASS OF KEY INFASTRUCTURE ASSETS - 1ST OFFENSE 511.100 02725 90J',
#        'TRAF IN MARIJUANA-> 5 LBS-2ND OR > OFFENSE 218A.1421(4) 42322 35A',
#        'FAILURE TO REPORT CHILD DEPEND NEGLECT/ABUSE 1ST OFF 620.030 02795 90Z',
#        'TBUT OR DISP FARM EQUIP $1,000 < $10,000 514.030 24152 23H',
#        'DIST OF MATTER PORTRAYING SEXUAL PERFORMANCE BY MINOR 1ST OF531.340 37280 370',
#        'COMMISSIONERS WARRANT (JUVENILE CUSTODY ORDER) 635.100(2) 02905 90Z',
#        'ASSAULT ON SERVICE ANIMAL - 2ND DEGREE 525.205 13213 90Z',
#        'RECEIPT OF CREDIT CARD LOST/ETC W/INTENT TO USE/TRANSFER 434.590 71265 26B',
#        'POSS CONT SUB-2ND DEGREE--BARBITUATE 218A.1416 42242 35A',
#        'TRAF CONT SUB-2ND DEG 2ND OR > OFFN (< 10 DU HALLUCINOGEN 218A.1413(1A) 42560 35A',
#        'TRAF CONT SUB-2ND DEG 1ST OFFN (>= 10 DU AMPHETAMINE) 218A.1413(1A) 42439 35A',
#        'RECEIPT OF CREDIT CARD IN VIOLATION KRS 434.570, 434.610 434.620 21220 26B',
#        'FRAUD BY AUTH PERSON/BUS/FIN INST $10000 OR > W/6 MO PERIOD 434.660 21171 26A'],
#       dtype=object)
